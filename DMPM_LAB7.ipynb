# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayushman2005-cmyk/DMPM_EXPERIMENTS/blob/main/DMPM_LAB7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
X = np.array([
    [2, 3],
    [3, 4],
    [4, 3],
    [10, 11],
    [11, 12],
    [12, 11]
])

# %%
Kmeans=KMeans(n_clusters=2, random_state=42, n_init=10)
labels=Kmeans.fit_predict(X)

# %%
print("Cluster Labels:")
print(labels)
# Out:
# Cluster Labels:
# [0 0 0 1 1 1]

# %%
print("\nCluster Centers:")
print(Kmeans.cluster_centers_)
# Out:
# Cluster Centers:
# [[ 3.          3.33333333]
#  [11.         11.33333333]]

# %%
plt.scatter(X[:,0],X[:,1],c=labels)
plt.scatter(
    Kmeans.cluster_centers_[:,0],
    Kmeans.cluster_centers_[:,1],
    marker="X",
    s=200
)
plt.xlabel("X")
plt.ylabel("Y")
plt.title("K-Means Clustering")
plt.show()
